# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('measurements.csv')

# %%
data
# Out:
#       size  num_threads  calc_t
# 0        3            1      10
# 1        3            1      10
# 2        3            1       4
# 3        3            1       4
# 4        3            1       4
# 5        3            1       4
# 6        3            1       4
# 7        3            1       4
# 8        3            1       4
# 9        3            1       4
# 10       3            2      59
# 11       3            2      59
# 12       3            2      51
# 13       3            2      77
# 14       3            2      75
# 15       3            2      56
# 16       3            2      48
# 17       3            2      69
# 18       3            2      49
# 19       3            2      58
# 20       3            3      80
# 21       3            3      81
# 22       3            3      64
# 23       3            3      86
# 24       3            3      67
# 25       3            3      79
# 26       3            3      66
# 27       3            3      65
# 28       3            3      71
# 29       3            3      67
# ..     ...          ...     ...
# 690  10000           16  264095
# 691  10000           16  259719
# 692  10000           16  259126
# 693  10000           16  259580
# 694  10000           16  260628
# 695  10000           16  258462
# 696  10000           16  262288
# 697  10000           16  258714
# 698  10000           16  261670
# 699  10000           16  259265
# 700  10000           24  261408
# 701  10000           24  259899
# 702  10000           24  261064
# 703  10000           24  257390
# 704  10000           24  260057
# 705  10000           24  258602
# 706  10000           24  260641
# 707  10000           24  255752
# 708  10000           24  258664
# 709  10000           24  258698
# 710  10000           32  258397
# 711  10000           32  256720
# 712  10000           32  256452
# 713  10000           32  255502
# 714  10000           32  258055
# 715  10000           32  257569
# 716  10000           32  256732
# 717  10000           32  260396
# 718  10000           32  258639
# 719  10000           32  258252
#
# [720 rows x 3 columns]

# %%
mean_data = data.groupby(['size','num_threads']).mean().reset_index()
mean_data.to_csv('mean_data.csv')
mean_data
# Out:
#      size  num_threads    calc_t
# 0       3            1       5.2
# 1       3            2      60.1
# 2       3            3      72.6
# 3       3            4      96.2
# 4       3            6     123.4
# 5       3            8     153.5
# 6       3           16     490.9
# 7       3           24     676.8
# 8       3           32     870.1
# 9      10            1       4.9
# 10     10            2      55.6
# 11     10            3      73.8
# 12     10            4      95.7
# 13     10            6     124.0
# 14     10            8     165.9
# 15     10           16     493.2
# 16     10           24     673.2
# 17     10           32     871.3
# 18    100            1      81.9
# 19    100            2     110.6
# 20    100            3     114.7
# 21    100            4     117.8
# 22    100            6     140.5
# 23    100            8     194.9
# 24    100           16     539.4
# 25    100           24     761.0
# 26    100           32     938.8
# 27    500            1    2319.4
# 28    500            2    1265.4
# 29    500            3    1005.7
# ..    ...          ...       ...
# 42   1000           16    3712.2
# 43   1000           24    3989.3
# 44   1000           32    3509.7
# 45   3000            1   75499.3
# 46   3000            2   46543.5
# 47   3000            3   31843.9
# 48   3000            4   23861.9
# 49   3000            6   29226.4
# 50   3000            8   22667.5
# 51   3000           16   27797.0
# 52   3000           24   27944.5
# 53   3000           32   25038.9
# 54   5000            1  209582.2
# 55   5000            2  128908.4
# 56   5000            3   86298.9
# 57   5000            4   65186.8
# 58   5000            6   64776.3
# 59   5000            8   62640.1
# 60   5000           16   68992.5
# 61   5000           24   67462.6
# 62   5000           32   66901.3
# 63  10000            1  838157.8
# 64  10000            2  515043.8
# 65  10000            3  345786.8
# 66  10000            4  261418.2
# 67  10000            6  310638.1
# 68  10000            8  251262.4
# 69  10000           16  260354.7
# 70  10000           24  259217.5
# 71  10000           32  257671.4
#
# [72 rows x 3 columns]

# %%
sizes = [3,10,100,500,1000,3000,5000,10000]
num_threads = [1,2,3,4,6,8,16,24,32]

print 'Графики Ускорения'

plt.figure(figsize=(10,5))

for s,i in zip(sizes,range(241,249)):
    calc_time = mean_data.ix[mean_data['size'] == s][['num_threads',\
                                                      'calc_t']]
    plt.subplot(i)
    plt.title('size = {0} x {0}'.format(s), fontsize=8)
    plt.plot(calc_time['num_threads'], \
             calc_time['calc_t'].values[0] * 1.0 / \
                                 np.array(calc_time['calc_t']), 'b.-')

plt.show()
# Out:
# Графики Ускорения

# %%
print 'Графики зависимости Времени от числа потоков'

plt.figure(figsize=(10,5))

for s,i in zip(sizes,range(241,249)):
    calc_time = mean_data.ix[mean_data['size'] == s][['num_threads',\
                                                      'calc_t']]
    plt.subplot(i)
    plt.title('size = {0} x {0}'.format(s), fontsize=8)
    plt.plot(calc_time['num_threads'], np.array(calc_time['calc_t']), 'b.-')

plt.show()
# Out:
# Графики зависимости Времени от числа потоков
